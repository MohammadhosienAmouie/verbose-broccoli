# %%
import pandas as pd
import numpy as np
import xlrd
import xlsxwriter

# %%
 pip install xlsxwriter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.3-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 5.2 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-79c76216-5ccf-4f7a-acfc-7fcd75ca792a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79c76216-5ccf-4f7a-acfc-7fcd75ca792a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ccs1.xlsx to ccs1.xlsx

# %%
data = pd.read_excel('ccs1.xlsx')
data.head(5)
# Out:
#    BatchNumber ShamsiDate       date      Time  CCS
# 0       140763   1401/5/6 2022-07-28  21:00:00  210
# 1       140767   1401/5/6 2022-07-28  23:00:00  311
# 2       140783   1401/5/7 2022-07-29  17:00:00  331
# 3       140790   1401/5/7 2022-07-29  21:00:00  273
# 4       140798   1401/5/7 2022-07-29  23:00:00  325

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c14af8f2-eb54-4e04-af9c-0e94da8532ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c14af8f2-eb54-4e04-af9c-0e94da8532ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving GPT.csv to GPT.csv

# %%
dama = pd.read_csv('GPT.csv')
dama.head(5)
# Out:
#           End Time           a          b           c          d
# 0   7/29/2022 9:00   38.091808  35.775489   43.220671  39.180692
# 1  7/29/2022 10:00   34.797486  29.695277   38.384375  35.672948
# 2  7/29/2022 11:00   33.809111  24.681773   35.523410  34.000966
# 3  7/29/2022 12:00   32.697439  22.742860   33.999745  32.566212
# 4  7/29/2022 13:00  106.732585  85.769741  122.679483  97.815417

# %%
dama[['Date', 'Time']] = dama['End Time'].str.split(' ', 1, expand=True)
dama.head(10)
# Out:
#           End Time           a           b           c           d       Date  \
# 0   7/29/2022 9:00   38.091808   35.775489   43.220671   39.180692  7/29/2022
# 1  7/29/2022 10:00   34.797486   29.695277   38.384375   35.672948  7/29/2022
# 2  7/29/2022 11:00   33.809111   24.681773   35.523410   34.000966  7/29/2022
# 3  7/29/2022 12:00   32.697439   22.742860   33.999745   32.566212  7/29/2022
# 4  7/29/2022 13:00  106.732585   85.769741  122.679483   97.815417  7/29/2022
# 5  7/29/2022 14:00  509.947761  429.464357  435.086188  488.464488  7/29/2022
# 6  7/29/2022 15:00  505.145851  410.672568  472.552583  528.876477  7/29/2022
# 7  7/29/2022 16:00  560.563363  529.022557  550.637065  582.069635  7/29/2022
# 8  7/29/2022 17:00  505.214009  480.819714  506.133621  523.790136  7/29/2022
# 9  7/29/2022 18:00  422.397801  424.996315  430.800840  416.476285  7/29/2022
#
#     Time
# 0   9:00
# 1  10:00
# 2  11:00
# 3  12:00
# 4  13:00
# 5  14:00
# 6  15:00
# 7  16:00
# 8  17:00
# 9  18:00

# %%
dama['Date']= pd.to_datetime(dama['Date'])

# %%
dama['Time']= pd.to_datetime(dama['Time'])
#dama['Time']= dama['Time'].astype(str)
dama.head(5)
# Out:
#           End Time           a          b           c          d       Date  \
# 0   7/29/2022 9:00   38.091808  35.775489   43.220671  39.180692 2022-07-29
# 1  7/29/2022 10:00   34.797486  29.695277   38.384375  35.672948 2022-07-29
# 2  7/29/2022 11:00   33.809111  24.681773   35.523410  34.000966 2022-07-29
# 3  7/29/2022 12:00   32.697439  22.742860   33.999745  32.566212 2022-07-29
# 4  7/29/2022 13:00  106.732585  85.769741  122.679483  97.815417 2022-07-29
#
#                  Time
# 0 2022-08-09 09:00:00
# 1 2022-08-09 10:00:00
# 2 2022-08-09 11:00:00
# 3 2022-08-09 12:00:00
# 4 2022-08-09 13:00:00

# %%
data['Time']= data['Time'].astype(str)
#data.head(3)
dama['Time']= dama['Time'].astype(str)

# %%
dama['Time'] = dama['Time'].str.split(' ').str.get(-1)
dama.head(5)
# Out:
#           End Time           a          b           c          d       Date  \
# 0   7/29/2022 9:00   38.091808  35.775489   43.220671  39.180692 2022-07-29
# 1  7/29/2022 10:00   34.797486  29.695277   38.384375  35.672948 2022-07-29
# 2  7/29/2022 11:00   33.809111  24.681773   35.523410  34.000966 2022-07-29
# 3  7/29/2022 12:00   32.697439  22.742860   33.999745  32.566212 2022-07-29
# 4  7/29/2022 13:00  106.732585  85.769741  122.679483  97.815417 2022-07-29
#
#        Time
# 0  09:00:00
# 1  10:00:00
# 2  11:00:00
# 3  12:00:00
# 4  13:00:00

# %%
#dama['Time']= pd.to_datetime(dama['Time'])
#dama['Time']= dama['Time'].astype(str)
#dama.head(5)

# %%
# mean1 =[]
# mean2 =[]
# mean3 =[]
# mean4 =[]

data['710TG1_AA01_TT28_AVG']=None
data['710TG1_AA01_TT29_AVG']=None
data['710TG1_AA01_TT30_AVG']=None
data['710TG1_AA01_TT31_AVG']=None

for ind1 in dama.index:
    for ind2 in  data.index:
      if dama['Date'][ind1] == data['date'][ind2]:
        if dama['Time'][ind1] in data['Time'][ind2]:
          data['710TG1_AA01_TT28_AVG'][ind2]=(dama['a'][ind1-1] + dama['a'][ind1 -2] + dama['a'][ind1 -3])/3 
          data['710TG1_AA01_TT29_AVG'][ind2]=(dama['b'][ind1-1] + dama['b'][ind1 -2] + dama['b'][ind1 -3])/3
          data['710TG1_AA01_TT30_AVG'][ind2]=(dama['c'][ind1-1] + dama['c'][ind1 -2] + dama['c'][ind1 -3])/3
          data['710TG1_AA01_TT31_AVG'][ind2]=(dama['d'][ind1-1] + dama['d'][ind1 -2] + dama['d'][ind1 -3])/3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data.head(16)
# Out:
#     BatchNumber ShamsiDate       date      Time  CCS 710TG1_AA01_TT28_AVG  \
# 0        140763   1401/5/6 2022-07-28  21:00:00  210                 None
# 1        140767   1401/5/6 2022-07-28  23:00:00  311                 None
# 2        140783   1401/5/7 2022-07-29  17:00:00  331           525.218992
# 3        140790   1401/5/7 2022-07-29  21:00:00  273           370.606308
# 4        140798   1401/5/7 2022-07-29  23:00:00  325           506.838449
# 5        140804   1401/5/8 2022-07-30  01:00:00  323           524.096876
# 6        140809   1401/5/8 2022-07-30  03:00:00  347           512.099962
# 7        140816   1401/5/8 2022-07-30  05:00:00  316            523.69133
# 8        140819   1401/5/8 2022-07-30  07:00:00  302           521.615287
# 9        140824   1401/5/8 2022-07-30  09:00:00  281            511.64545
# 10       140831   1401/5/8 2022-07-30  11:00:00  302           511.025796
# 11       140836   1401/5/8 2022-07-30  13:00:00  293           523.128711
# 12       140845   1401/5/8 2022-07-30  15:00:00  305           534.673689
# 13       140851   1401/5/8 2022-07-30  17:00:00  300           526.564295
# 14       140855   1401/5/8 2022-07-30  19:00:00  292           528.667871
# 15       140863   1401/5/8 2022-07-30  21:00:00  273           495.366989
#
#    710TG1_AA01_TT29_AVG 710TG1_AA01_TT30_AVG 710TG1_AA01_TT31_AVG
# 0                  None                 None                 None
# 1                  None                 None                 None
# 2            456.386494           486.091945           533.136866
# 3            361.602469           386.692165            382.36647
# 4            478.295873           506.303097           543.563999
# 5             496.80649           517.117267           548.638473
# 6            477.910531           500.892314            534.15081
# 7            491.334333           508.093554           546.765273
# 8            492.418199           509.998764           547.091204
# 9            476.732534           504.766274            538.77565
# 10           469.668149           505.550994           540.042487
# 11           483.208193           518.609936           551.765486
# 12           496.519146            534.85849           562.718547
# 13           488.952231           529.145106           554.890467
# 14           491.121792           527.807531           552.834908
# 15           453.721048           497.051381           513.190474

# %%
data.to_excel('sample_data.xlsx', sheet_name='sheet1', index=False)
